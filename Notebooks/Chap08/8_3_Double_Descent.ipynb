# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to make a local copy of the MNIST 1D repository
# !git clone https://github.com/greydanus/mnist1d

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cpu

# %%
# %matplotlib inline

# %%
plt.style.use("/home/cagas65/gkeyll/postgkyl/src/postgkyl/output/postgkyl.mplstyle")

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./sample_data/mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./sample_data/mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Length of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers of size 100
  # And ReLU activations between them
  model = nn.Sequential(
    nn.Linear(D_i, D_k),
    nn.ReLU(),
    nn.Linear(D_k, D_k),
    nn.ReLU(),
    nn.Linear(D_k, D_o)
  )

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model

# %%
def fit_model(model, data):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  # create 100 dummy data points and store in data loader class
  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True,
                           worker_init_fn=np.random.seed(1))

  # loop over the dataset n_epoch times
  n_epoch = 1000

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TO DO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400])
errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden])
    # Train the model
    errors_train, errors_test = fit_model(model, data)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.301389, train error 89.12,  test loss 2.300167, test error 89.07
# Epoch   100, train loss 1.881318, train error 70.72,  test loss 1.727130, test error 68.20
# Epoch   200, train loss 1.868757, train error 69.68,  test loss 1.716872, test error 68.25
# Epoch   300, train loss 1.864041, train error 70.62,  test loss 1.706856, test error 68.03
# Epoch   400, train loss 1.860350, train error 69.75,  test loss 1.714416, test error 67.72
# Epoch   500, train loss 1.862050, train error 71.00,  test loss 1.701469, test error 68.45
# Epoch   600, train loss 1.858712, train error 70.30,  test loss 1.718581, test error 68.18
# Epoch   700, train loss 1.856824, train error 70.75,  test loss 1.713464, test error 68.20
# Epoch   800, train loss 1.856187, train error 70.60,  test loss 1.714342, test error 68.47
# Epoch   900, train loss 1.856885, train error 70.85,  test loss 1.719433, test error 68.68
# Training model with   4 hidden variables
# Epoch     0, train loss 2.275641, train error 86.30,  test loss 2.261976, test error 86.05
# Epoch   100, train loss 1.778910, train error 65.80,  test loss 1.610310, test error 63.25
# Epoch   200, train loss 1.768971, train error 65.93,  test loss 1.624173, test error 63.53
# Epoch   300, train loss 1.762306, train error 65.05,  test loss 1.612777, test error 62.90
# Epoch   400, train loss 1.751150, train error 64.45,  test loss 1.613269, test error 62.42
# Epoch   500, train loss 1.747132, train error 64.35,  test loss 1.618100, test error 62.67
# Epoch   600, train loss 1.743397, train error 64.15,  test loss 1.621296, test error 62.70
# Epoch   700, train loss 1.741412, train error 64.78,  test loss 1.607515, test error 62.50
# Epoch   800, train loss 1.739238, train error 64.18,  test loss 1.608818, test error 63.25
# Epoch   900, train loss 1.741297, train error 64.05,  test loss 1.622473, test error 62.42
# Training model with   6 hidden variables
# Epoch     0, train loss 2.239921, train error 83.03,  test loss 2.229297, test error 82.53
# Epoch   100, train loss 1.650132, train error 58.05,  test loss 1.501980, test error 56.60
# Epoch   200, train loss 1.574428, train error 54.50,  test loss 1.429898, test error 53.35
# Epoch   300, train loss 1.558406, train error 54.03,  test loss 1.437914, test error 53.70
# Epoch   400, train loss 1.552721, train error 53.58,  test loss 1.437664, test error 53.38
# Epoch   500, train loss 1.546862, train error 53.58,  test loss 1.444304, test error 53.28
# Epoch   600, train loss 1.552363, train error 54.08,  test loss 1.440612, test error 53.65
# Epoch   700, train loss 1.549968, train error 53.38,  test loss 1.438687, test error 53.17
# Epoch   800, train loss 1.542894, train error 53.70,  test loss 1.440789, test error 53.28
# Epoch   900, train loss 1.545416, train error 53.58,  test loss 1.439005, test error 54.10
# Training model with   8 hidden variables
# Epoch     0, train loss 2.208347, train error 81.88,  test loss 2.191050, test error 81.53
# Epoch   100, train loss 1.605732, train error 57.15,  test loss 1.455486, test error 55.47
# Epoch   200, train loss 1.574092, train error 56.10,  test loss 1.474717, test error 55.40
# Epoch   300, train loss 1.553063, train error 55.12,  test loss 1.458935, test error 55.45
# Epoch   400, train loss 1.512812, train error 52.53,  test loss 1.429386, test error 53.10
# Epoch   500, train loss 1.489970, train error 51.62,  test loss 1.402514, test error 52.00
# Epoch   600, train loss 1.476474, train error 50.90,  test loss 1.384436, test error 50.80
# Epoch   700, train loss 1.472470, train error 51.08,  test loss 1.391816, test error 50.05
# Epoch   800, train loss 1.466263, train error 50.65,  test loss 1.378735, test error 50.03
# Epoch   900, train loss 1.460625, train error 50.10,  test loss 1.382851, test error 50.10
# Training model with  10 hidden variables
# Epoch     0, train loss 2.264835, train error 85.93,  test loss 2.255814, test error 85.53
# Epoch   100, train loss 1.543008, train error 53.85,  test loss 1.428247, test error 53.42
# Epoch   200, train loss 1.484003, train error 51.12,  test loss 1.395357, test error 52.65
# Epoch   300, train loss 1.456435, train error 51.22,  test loss 1.366167, test error 51.22
# Epoch   400, train loss 1.439568, train error 49.70,  test loss 1.368851, test error 51.00
# Epoch   500, train loss 1.425525, train error 49.65,  test loss 1.363545, test error 50.53
# Epoch   600, train loss 1.430950, train error 50.12,  test loss 1.382637, test error 51.42
# Epoch   700, train loss 1.416791, train error 49.25,  test loss 1.367897, test error 50.35
# Epoch   800, train loss 1.427559, train error 49.10,  test loss 1.385451, test error 51.05
# Epoch   900, train loss 1.412555, train error 49.12,  test loss 1.389161, test error 51.35
# Training model with  14 hidden variables
# Epoch     0, train loss 2.179213, train error 82.00,  test loss 2.149281, test error 80.88
# Epoch   100, train loss 1.447860, train error 48.95,  test loss 1.332399, test error 49.72
# Epoch   200, train loss 1.364747, train error 45.40,  test loss 1.314165, test error 48.83
# Epoch   300, train loss 1.327829, train error 44.35,  test loss 1.317800, test error 49.08
# Epoch   400, train loss 1.303221, train error 43.80,  test loss 1.337333, test error 49.53
# Epoch   500, train loss 1.278898, train error 43.47,  test loss 1.355251, test error 50.30
# Epoch   600, train loss 1.270183, train error 43.15,  test loss 1.380100, test error 50.97
# Epoch   700, train loss 1.254470, train error 42.83,  test loss 1.399253, test error 50.80
# Epoch   800, train loss 1.254699, train error 43.53,  test loss 1.416188, test error 51.08
# Epoch   900, train loss 1.247675, train error 43.33,  test loss 1.430180, test error 51.25
# Training model with  18 hidden variables
# Epoch     0, train loss 2.142301, train error 78.32,  test loss 2.082177, test error 77.60
# Epoch   100, train loss 1.298247, train error 43.17,  test loss 1.258998, test error 46.85
# Epoch   200, train loss 1.215021, train error 40.20,  test loss 1.308203, test error 47.78
# Epoch   300, train loss 1.187079, train error 39.70,  test loss 1.350159, test error 47.50
# Epoch   400, train loss 1.157223, train error 39.40,  test loss 1.380015, test error 48.17
# Epoch   500, train loss 1.147567, train error 38.75,  test loss 1.417669, test error 48.60
# Epoch   600, train loss 1.131761, train error 38.35,  test loss 1.447847, test error 49.50
# Epoch   700, train loss 1.118577, train error 37.95,  test loss 1.490417, test error 50.10
# Epoch   800, train loss 1.106652, train error 38.12,  test loss 1.520388, test error 50.22
# Epoch   900, train loss 1.104839, train error 37.90,  test loss 1.535651, test error 50.45
# Training model with  22 hidden variables
# Epoch     0, train loss 2.145735, train error 79.57,  test loss 2.095644, test error 77.78
# Epoch   100, train loss 1.299697, train error 43.95,  test loss 1.344397, test error 49.88
# Epoch   200, train loss 1.144733, train error 38.20,  test loss 1.361781, test error 47.45
# Epoch   300, train loss 1.080065, train error 36.35,  test loss 1.404175, test error 47.95
# Epoch   400, train loss 1.053347, train error 35.60,  test loss 1.515229, test error 49.17
# Epoch   500, train loss 1.015130, train error 34.53,  test loss 1.544723, test error 49.22
# Epoch   600, train loss 1.001729, train error 34.05,  test loss 1.588179, test error 48.88
# Epoch   700, train loss 1.002319, train error 33.90,  test loss 1.640028, test error 49.22
# Epoch   800, train loss 0.972812, train error 32.72,  test loss 1.688843, test error 49.12
# Epoch   900, train loss 0.983291, train error 33.60,  test loss 1.721198, test error 50.85
# Training model with  26 hidden variables
# Epoch     0, train loss 2.162966, train error 80.47,  test loss 2.145717, test error 80.72
# Epoch   100, train loss 1.199706, train error 38.67,  test loss 1.310861, test error 49.03
# Epoch   200, train loss 1.069552, train error 35.68,  test loss 1.427701, test error 51.08
# Epoch   300, train loss 1.008078, train error 33.43,  test loss 1.533754, test error 51.50
# Epoch   400, train loss 0.964959, train error 32.32,  test loss 1.655862, test error 52.88
# Epoch   500, train loss 0.933287, train error 31.25,  test loss 1.711192, test error 53.22
# Epoch   600, train loss 0.918195, train error 30.90,  test loss 1.782506, test error 53.25
# Epoch   700, train loss 0.917339, train error 31.20,  test loss 1.877397, test error 54.20
# Epoch   800, train loss 0.899089, train error 30.22,  test loss 1.905438, test error 53.45
# Epoch   900, train loss 0.868505, train error 30.32,  test loss 1.985147, test error 54.53
# Training model with  30 hidden variables
# Epoch     0, train loss 2.130411, train error 78.38,  test loss 2.089275, test error 78.28
# Epoch   100, train loss 1.115012, train error 36.53,  test loss 1.321178, test error 48.03
# Epoch   200, train loss 0.921941, train error 31.18,  test loss 1.508650, test error 49.67
# Epoch   300, train loss 0.814922, train error 26.82,  test loss 1.740147, test error 51.20
# Epoch   400, train loss 0.766917, train error 26.53,  test loss 1.917554, test error 52.15
# Epoch   500, train loss 0.715858, train error 23.65,  test loss 2.082080, test error 52.97
# Epoch   600, train loss 0.703337, train error 23.05,  test loss 2.230137, test error 52.62
# Epoch   700, train loss 0.662532, train error 21.45,  test loss 2.342490, test error 53.62
# Epoch   800, train loss 0.669900, train error 23.72,  test loss 2.517864, test error 54.62
# Epoch   900, train loss 0.633691, train error 21.18,  test loss 2.669674, test error 54.95
# Training model with  35 hidden variables
# Epoch     0, train loss 2.130320, train error 79.07,  test loss 2.090108, test error 78.70
# Epoch   100, train loss 1.012255, train error 32.45,  test loss 1.377067, test error 47.97
# Epoch   200, train loss 0.778945, train error 25.90,  test loss 1.722198, test error 52.28
# Epoch   300, train loss 0.645560, train error 21.65,  test loss 2.006596, test error 52.53
# Epoch   400, train loss 0.580994, train error 19.18,  test loss 2.381940, test error 54.08
# Epoch   500, train loss 0.510551, train error 16.90,  test loss 2.732800, test error 54.75
# Epoch   600, train loss 0.477902, train error 16.70,  test loss 3.147050, test error 55.17
# Epoch   700, train loss 0.483375, train error 16.88,  test loss 3.520409, test error 56.05
# Epoch   800, train loss 0.435653, train error 15.60,  test loss 3.900913, test error 56.55
# Epoch   900, train loss 0.446124, train error 15.75,  test loss 4.190525, test error 57.60
# Training model with  40 hidden variables
# Epoch     0, train loss 2.117080, train error 78.38,  test loss 2.086926, test error 77.68
# Epoch   100, train loss 0.962809, train error 30.65,  test loss 1.416072, test error 49.83
# Epoch   200, train loss 0.712463, train error 24.12,  test loss 1.818648, test error 51.97
# Epoch   300, train loss 0.542480, train error 17.95,  test loss 2.418280, test error 54.97
# Epoch   400, train loss 0.474618, train error 15.97,  test loss 3.075570, test error 55.70
# Epoch   500, train loss 0.434236, train error 14.43,  test loss 3.757279, test error 57.85
# Epoch   600, train loss 0.312352, train error 9.82,  test loss 4.390403, test error 57.88
# Epoch   700, train loss 0.307573, train error 10.82,  test loss 5.080605, test error 57.25
# Epoch   800, train loss 0.277168, train error 9.65,  test loss 5.754025, test error 57.12
# Epoch   900, train loss 0.289782, train error 10.15,  test loss 6.516140, test error 58.62
# Training model with  45 hidden variables
# Epoch     0, train loss 2.119071, train error 79.00,  test loss 2.089648, test error 78.75
# Epoch   100, train loss 0.806444, train error 26.10,  test loss 1.503646, test error 50.75
# Epoch   200, train loss 0.466478, train error 14.95,  test loss 2.290399, test error 53.05
# Epoch   300, train loss 0.306623, train error 10.35,  test loss 3.467221, test error 54.97
# Epoch   400, train loss 0.265202, train error 9.72,  test loss 4.709291, test error 56.45
# Epoch   500, train loss 0.207549, train error 7.53,  test loss 5.965776, test error 56.97
# Epoch   600, train loss 0.163075, train error 5.72,  test loss 7.078512, test error 57.10
# Epoch   700, train loss 0.167711, train error 5.68,  test loss 8.082237, test error 56.20
# Epoch   800, train loss 0.317807, train error 10.28,  test loss 9.103506, test error 58.10
# Epoch   900, train loss 0.006478, train error 0.00,  test loss 9.886998, test error 56.88
# Training model with  50 hidden variables
# Epoch     0, train loss 2.095511, train error 78.07,  test loss 2.059565, test error 77.25
# Epoch   100, train loss 0.733668, train error 22.50,  test loss 1.561019, test error 50.75
# Epoch   200, train loss 0.382709, train error 11.82,  test loss 2.552814, test error 54.08
# Epoch   300, train loss 0.175417, train error 4.05,  test loss 3.987656, test error 53.25
# Epoch   400, train loss 0.047563, train error 0.25,  test loss 5.629011, test error 55.15
# Epoch   500, train loss 0.016835, train error 0.00,  test loss 6.854939, test error 55.33
# Epoch   600, train loss 0.009938, train error 0.00,  test loss 7.609076, test error 55.05
# Epoch   700, train loss 0.006871, train error 0.00,  test loss 8.160346, test error 55.47
# Epoch   800, train loss 0.005238, train error 0.00,  test loss 8.587589, test error 55.55
# Epoch   900, train loss 0.004152, train error 0.00,  test loss 8.936943, test error 55.67
# Training model with  55 hidden variables
# Epoch     0, train loss 2.057260, train error 76.07,  test loss 2.027732, test error 76.72
# Epoch   100, train loss 0.621198, train error 19.32,  test loss 1.695072, test error 50.95
# Epoch   200, train loss 0.199425, train error 4.57,  test loss 3.194859, test error 54.50
# Epoch   300, train loss 0.033289, train error 0.00,  test loss 4.838181, test error 55.58
# Epoch   400, train loss 0.013496, train error 0.00,  test loss 5.770109, test error 56.10
# Epoch   500, train loss 0.007876, train error 0.00,  test loss 6.359732, test error 55.88
# Epoch   600, train loss 0.005462, train error 0.00,  test loss 6.778316, test error 55.88
# Epoch   700, train loss 0.004149, train error 0.00,  test loss 7.110941, test error 55.88
# Epoch   800, train loss 0.003298, train error 0.00,  test loss 7.386033, test error 55.85
# Epoch   900, train loss 0.002712, train error 0.00,  test loss 7.617356, test error 55.85
# Training model with  60 hidden variables
# Epoch     0, train loss 2.073733, train error 78.35,  test loss 2.022283, test error 77.82
# Epoch   100, train loss 0.510825, train error 14.55,  test loss 1.806142, test error 51.12
# Epoch   200, train loss 0.098030, train error 0.78,  test loss 3.457706, test error 53.90
# Epoch   300, train loss 0.020590, train error 0.00,  test loss 4.835848, test error 54.00
# Epoch   400, train loss 0.009905, train error 0.00,  test loss 5.560034, test error 54.28
# Epoch   500, train loss 0.006223, train error 0.00,  test loss 6.036111, test error 54.40
# Epoch   600, train loss 0.004465, train error 0.00,  test loss 6.381410, test error 54.38
# Epoch   700, train loss 0.003403, train error 0.00,  test loss 6.660354, test error 54.47
# Epoch   800, train loss 0.002737, train error 0.00,  test loss 6.886639, test error 54.33
# Epoch   900, train loss 0.002270, train error 0.00,  test loss 7.083924, test error 54.30
# Training model with  70 hidden variables
# Epoch     0, train loss 2.051477, train error 76.25,  test loss 1.990872, test error 76.03
# Epoch   100, train loss 0.391618, train error 10.05,  test loss 1.940969, test error 52.70
# Epoch   200, train loss 0.036672, train error 0.00,  test loss 3.681353, test error 53.22
# Epoch   300, train loss 0.011477, train error 0.00,  test loss 4.568828, test error 53.42
# Epoch   400, train loss 0.006363, train error 0.00,  test loss 5.059438, test error 53.62
# Epoch   500, train loss 0.004258, train error 0.00,  test loss 5.392577, test error 53.70
# Epoch   600, train loss 0.003135, train error 0.00,  test loss 5.643604, test error 53.67
# Epoch   700, train loss 0.002447, train error 0.00,  test loss 5.849005, test error 53.80
# Epoch   800, train loss 0.001994, train error 0.00,  test loss 6.018458, test error 53.80
# Epoch   900, train loss 0.001674, train error 0.00,  test loss 6.163235, test error 53.88
# Training model with  80 hidden variables
# Epoch     0, train loss 2.054833, train error 76.30,  test loss 2.006338, test error 75.93
# Epoch   100, train loss 0.268147, train error 5.70,  test loss 2.073994, test error 51.88
# Epoch   200, train loss 0.020139, train error 0.00,  test loss 3.413516, test error 52.70
# Epoch   300, train loss 0.008041, train error 0.00,  test loss 3.967224, test error 53.10
# Epoch   400, train loss 0.004734, train error 0.00,  test loss 4.293980, test error 53.55
# Epoch   500, train loss 0.003269, train error 0.00,  test loss 4.529636, test error 53.55
# Epoch   600, train loss 0.002451, train error 0.00,  test loss 4.707826, test error 53.40
# Epoch   700, train loss 0.001947, train error 0.00,  test loss 4.854722, test error 53.33
# Epoch   800, train loss 0.001603, train error 0.00,  test loss 4.976035, test error 53.28
# Epoch   900, train loss 0.001356, train error 0.00,  test loss 5.082283, test error 53.40
# Training model with  90 hidden variables
# Epoch     0, train loss 2.009398, train error 74.28,  test loss 1.952491, test error 75.68
# Epoch   100, train loss 0.143780, train error 1.05,  test loss 2.114403, test error 50.78
# Epoch   200, train loss 0.015250, train error 0.00,  test loss 3.181256, test error 51.10
# Epoch   300, train loss 0.006772, train error 0.00,  test loss 3.619204, test error 50.95
# Epoch   400, train loss 0.004088, train error 0.00,  test loss 3.887041, test error 51.20
# Epoch   500, train loss 0.002874, train error 0.00,  test loss 4.079803, test error 51.20
# Epoch   600, train loss 0.002184, train error 0.00,  test loss 4.230123, test error 51.12
# Epoch   700, train loss 0.001745, train error 0.00,  test loss 4.352855, test error 51.28
# Epoch   800, train loss 0.001445, train error 0.00,  test loss 4.458358, test error 51.50
# Epoch   900, train loss 0.001225, train error 0.00,  test loss 4.549231, test error 51.58
# Training model with 100 hidden variables
# Epoch     0, train loss 1.975834, train error 73.15,  test loss 1.909148, test error 74.68
# Epoch   100, train loss 0.082249, train error 0.10,  test loss 2.365974, test error 51.62
# Epoch   200, train loss 0.011992, train error 0.00,  test loss 3.225657, test error 52.50
# Epoch   300, train loss 0.005616, train error 0.00,  test loss 3.593812, test error 52.30
# Epoch   400, train loss 0.003517, train error 0.00,  test loss 3.825368, test error 52.47
# Epoch   500, train loss 0.002504, train error 0.00,  test loss 3.995212, test error 52.47
# Epoch   600, train loss 0.001918, train error 0.00,  test loss 4.129482, test error 52.78
# Epoch   700, train loss 0.001542, train error 0.00,  test loss 4.239625, test error 52.72
# Epoch   800, train loss 0.001281, train error 0.00,  test loss 4.334272, test error 52.75
# Epoch   900, train loss 0.001091, train error 0.00,  test loss 4.414526, test error 52.88
# Training model with 120 hidden variables
# Epoch     0, train loss 1.982795, train error 72.65,  test loss 1.924665, test error 74.05
# Epoch   100, train loss 0.053646, train error 0.03,  test loss 2.177436, test error 49.83
# Epoch   200, train loss 0.009975, train error 0.00,  test loss 2.802589, test error 50.03
# Epoch   300, train loss 0.004886, train error 0.00,  test loss 3.081286, test error 50.28
# Epoch   400, train loss 0.003110, train error 0.00,  test loss 3.259617, test error 50.30
# Epoch   500, train loss 0.002234, train error 0.00,  test loss 3.393352, test error 50.30
# Epoch   600, train loss 0.001723, train error 0.00,  test loss 3.497936, test error 50.33
# Epoch   700, train loss 0.001392, train error 0.00,  test loss 3.583793, test error 50.30
# Epoch   800, train loss 0.001161, train error 0.00,  test loss 3.657849, test error 50.38
# Epoch   900, train loss 0.000991, train error 0.00,  test loss 3.722513, test error 50.30
# Training model with 140 hidden variables
# Epoch     0, train loss 1.939568, train error 70.32,  test loss 1.866955, test error 71.93
# Epoch   100, train loss 0.037819, train error 0.00,  test loss 2.135169, test error 48.97
# Epoch   200, train loss 0.008301, train error 0.00,  test loss 2.640246, test error 49.53
# Epoch   300, train loss 0.004237, train error 0.00,  test loss 2.877586, test error 49.70
# Epoch   400, train loss 0.002753, train error 0.00,  test loss 3.032902, test error 49.65
# Epoch   500, train loss 0.001997, train error 0.00,  test loss 3.146395, test error 49.70
# Epoch   600, train loss 0.001550, train error 0.00,  test loss 3.236777, test error 49.85
# Epoch   700, train loss 0.001258, train error 0.00,  test loss 3.312308, test error 49.80
# Epoch   800, train loss 0.001053, train error 0.00,  test loss 3.376188, test error 49.85
# Epoch   900, train loss 0.000902, train error 0.00,  test loss 3.432561, test error 49.92
# Training model with 160 hidden variables
# Epoch     0, train loss 1.935395, train error 71.35,  test loss 1.855394, test error 70.85
# Epoch   100, train loss 0.029580, train error 0.00,  test loss 2.079413, test error 48.25
# Epoch   200, train loss 0.007243, train error 0.00,  test loss 2.487448, test error 48.55
# Epoch   300, train loss 0.003792, train error 0.00,  test loss 2.688175, test error 48.60
# Epoch   400, train loss 0.002483, train error 0.00,  test loss 2.821211, test error 48.62
# Epoch   500, train loss 0.001816, train error 0.00,  test loss 2.920179, test error 48.70
# Epoch   600, train loss 0.001416, train error 0.00,  test loss 2.999859, test error 48.83
# Epoch   700, train loss 0.001153, train error 0.00,  test loss 3.065902, test error 48.90
# Epoch   800, train loss 0.000968, train error 0.00,  test loss 3.122063, test error 48.97
# Epoch   900, train loss 0.000830, train error 0.00,  test loss 3.171065, test error 48.92
# Training model with 180 hidden variables
# Epoch     0, train loss 1.935199, train error 71.88,  test loss 1.859285, test error 73.55
# Epoch   100, train loss 0.025329, train error 0.00,  test loss 2.044675, test error 48.60
# Epoch   200, train loss 0.006735, train error 0.00,  test loss 2.400822, test error 48.67
# Epoch   300, train loss 0.003573, train error 0.00,  test loss 2.577156, test error 48.50
# Epoch   400, train loss 0.002367, train error 0.00,  test loss 2.695972, test error 48.42
# Epoch   500, train loss 0.001740, train error 0.00,  test loss 2.785619, test error 48.47
# Epoch   600, train loss 0.001362, train error 0.00,  test loss 2.858112, test error 48.58
# Epoch   700, train loss 0.001112, train error 0.00,  test loss 2.917114, test error 48.53
# Epoch   800, train loss 0.000935, train error 0.00,  test loss 2.968843, test error 48.58
# Epoch   900, train loss 0.000803, train error 0.00,  test loss 3.013749, test error 48.50
# Training model with 200 hidden variables
# Epoch     0, train loss 1.920866, train error 71.40,  test loss 1.844207, test error 71.75
# Epoch   100, train loss 0.021098, train error 0.00,  test loss 2.081836, test error 48.15
# Epoch   200, train loss 0.006027, train error 0.00,  test loss 2.415435, test error 48.17
# Epoch   300, train loss 0.003273, train error 0.00,  test loss 2.584340, test error 48.25
# Epoch   400, train loss 0.002186, train error 0.00,  test loss 2.698582, test error 48.22
# Epoch   500, train loss 0.001615, train error 0.00,  test loss 2.784945, test error 48.35
# Epoch   600, train loss 0.001268, train error 0.00,  test loss 2.853843, test error 48.45
# Epoch   700, train loss 0.001038, train error 0.00,  test loss 2.911017, test error 48.28
# Epoch   800, train loss 0.000874, train error 0.00,  test loss 2.960913, test error 48.25
# Epoch   900, train loss 0.000752, train error 0.00,  test loss 3.004387, test error 48.17
# Training model with 250 hidden variables
# Epoch     0, train loss 1.924190, train error 70.57,  test loss 1.845814, test error 72.82
# Epoch   100, train loss 0.017063, train error 0.00,  test loss 1.826856, test error 46.25
# Epoch   200, train loss 0.005306, train error 0.00,  test loss 2.067881, test error 46.30
# Epoch   300, train loss 0.002952, train error 0.00,  test loss 2.195805, test error 46.00
# Epoch   400, train loss 0.001992, train error 0.00,  test loss 2.284438, test error 45.78
# Epoch   500, train loss 0.001483, train error 0.00,  test loss 2.350616, test error 45.83
# Epoch   600, train loss 0.001170, train error 0.00,  test loss 2.405015, test error 45.67
# Epoch   700, train loss 0.000961, train error 0.00,  test loss 2.450409, test error 45.83
# Epoch   800, train loss 0.000811, train error 0.00,  test loss 2.488919, test error 45.80
# Epoch   900, train loss 0.000700, train error 0.00,  test loss 2.523078, test error 45.85
# Training model with 300 hidden variables
# Epoch     0, train loss 1.846465, train error 66.50,  test loss 1.787874, test error 69.72
# Epoch   100, train loss 0.014196, train error 0.00,  test loss 1.862431, test error 46.75
# Epoch   200, train loss 0.004766, train error 0.00,  test loss 2.075049, test error 46.78
# Epoch   300, train loss 0.002710, train error 0.00,  test loss 2.190551, test error 46.72
# Epoch   400, train loss 0.001845, train error 0.00,  test loss 2.271090, test error 46.92
# Epoch   500, train loss 0.001381, train error 0.00,  test loss 2.332105, test error 46.78
# Epoch   600, train loss 0.001095, train error 0.00,  test loss 2.381567, test error 46.60
# Epoch   700, train loss 0.000901, train error 0.00,  test loss 2.423210, test error 46.62
# Epoch   800, train loss 0.000763, train error 0.00,  test loss 2.459150, test error 46.70
# Epoch   900, train loss 0.000659, train error 0.00,  test loss 2.490754, test error 46.60
# Training model with 400 hidden variables
# Epoch     0, train loss 1.848953, train error 66.12,  test loss 1.770594, test error 68.47
# Epoch   100, train loss 0.011882, train error 0.00,  test loss 1.768582, test error 46.33
# Epoch   200, train loss 0.004232, train error 0.00,  test loss 1.944883, test error 46.30
# Epoch   300, train loss 0.002438, train error 0.00,  test loss 2.044901, test error 46.45
# Epoch   400, train loss 0.001678, train error 0.00,  test loss 2.114617, test error 46.53
# Epoch   500, train loss 0.001264, train error 0.00,  test loss 2.167529, test error 46.58
# Epoch   600, train loss 0.001006, train error 0.00,  test loss 2.210201, test error 46.55
# Epoch   700, train loss 0.000831, train error 0.00,  test loss 2.246145, test error 46.58
# Epoch   800, train loss 0.000705, train error 0.00,  test loss 2.277403, test error 46.60
# Epoch   900, train loss 0.000611, train error 0.00,  test loss 2.305105, test error 46.45

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all,color='C0',label='train')
ax.plot(hidden_variables, errors_test_all, color='C1',label='test')
ax.set_ylim(0,70)
ax.set_xlabel('No hidden variables'); ax.set_ylabel('Error')
ax.legend()
ax.grid()
plt.show()
